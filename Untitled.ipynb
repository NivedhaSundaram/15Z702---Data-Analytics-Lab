# %%
import numpy as np
import pandas as pd
from subprocess import check_output
print(check_output(["ls", "../input"]).decode("utf8"))
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline
from plotly import tools
import plotly.plotly as py
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.figure_factory as ff
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.model_selection import cross_val_score
from xgboost import XGBClassifier, plot_importance
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-00c27f7e7868> in <module>()
#       2 import pandas as pd
#       3 from subprocess import check_output
# ----> 4 print(check_output(["ls", "../input"]).decode("utf8"))
#       5 import matplotlib.pyplot as plt
#       6 import seaborn as sns
#
# C:\ProgramData\Anaconda3\lib\subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     334
#     335     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 336                **kwargs).stdout
#     337
#     338
#
# C:\ProgramData\Anaconda3\lib\subprocess.py in run(input, timeout, check, *popenargs, **kwargs)
#     401         kwargs['stdin'] = PIPE
#     402
# --> 403     with Popen(*popenargs, **kwargs) as process:
#     404         try:
#     405             stdout, stderr = process.communicate(input, timeout=timeout)
#
# ...

# %%
import pandas as pd
df=pd.read_csv("Z:\sample.csv")
print(df)
# Out:
#      F     G  Good Good.1    Vg Good.2  Y  Unmarried  V  Paid   ...     \
# 0    M   OBC    Vg     Vg    Vg     Vg  N  Unmarried  V  Paid   ...
# 1    F   OBC  Good   Good    Vg   Good  N  Unmarried  V  Paid   ...
# 2    M  MOBC  Pass   Good    Vg   Good  N  Unmarried  V  Paid   ...
# 3    M     G  Good   Good    Vg     Vg  N  Unmarried  V  Paid   ...
# 4    M   OBC    Vg   Good    Vg     Vg  N  Unmarried  V  Paid   ...
# 5    F   OBC  Good     Vg  Good   Good  N  Unmarried  V  Paid   ...
# 6    F   OBC  Good   Good  Good   Good  N  Unmarried  V  Paid   ...
# 7    F  MOBC    Vg   Good  Good     Vg  Y  Unmarried  V  Paid   ...
# 8    F   OBC    Vg     Vg  Good     Vg  Y  Unmarried  V  Paid   ...
# 9    M    ST    Vg     Vg  Good     Vg  N  Unmarried  V  Paid   ...
# 10   F   OBC    Vg     Vg  Good     Vg  N  Unmarried  V  Paid   ...
# 11   M   OBC  Good   Good  Good   Good  Y  Unmarried  V  Paid   ...
# 12   M   OBC  Good   Good  Pass     Vg  N  Unmarried  V  Paid   ...
# ...

# %%
df.describe()
# Out:
#           F    G  Good Good.1   Vg Good.2    Y  Unmarried    V  Paid  ...    \
# count   130  130   130    130  130    130  130        130  129   130  ...
# unique    2    5     4      4    4      4    2          1    2     2  ...
# top       M  OBC  Good   Good   Vg   Good    N  Unmarried    V  Paid  ...
# freq     72   57    58     64   62     53   78        130   90    75  ...
#
#          Um   10   Farmer  Housewife  Large     Poor  Govt  Asm  Small Good.3
# count   130  130      130        130    130      130   130  130    130    130
# unique    6    6        5          5      3        3     2    4      3      3
# top      Um   Um  Service  Housewife  Large  Average  Govt  Eng  Small   Good
# freq     39   52       38        114     57       59    90   62     77     55
#
# [4 rows x 22 columns]

# %%
print(len(df))
df.isnull().sum()
# Out:
# 130
# F            0
# G            0
# Good         0
# Good.1       0
# Vg           0
# Good.2       0
# Y            0
# Unmarried    0
# V            1
# Paid         0
# Medium       0
# Average      0
# Um           0
# 10           0
# Farmer       0
# Housewife    0
# Large        0
# Poor         0
# Govt         0
# Asm          0
# Small        0
# Good.3       0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
df.boxplot(column='F', by='Borough', rot=90)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-570068ee7b95> in <module>()
# ----> 1 df.boxplot(column='F', by='Borough', rot=90)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#    2255     ax = boxplot(self, column=column, by=by, ax=ax, fontsize=fontsize,
#    2256                  grid=grid, rot=rot, figsize=figsize, layout=layout,
# -> 2257                  return_type=return_type, **kwds)
#    2258     plt.draw_if_interactive()
#    2259     return ax
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in boxplot(data, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#    2224                                          by=by, grid=grid, figsize=figsize,
# ...

# %%
df.boxplot(column='initial_cost', by='G', rot=90)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-b4896007df5a> in <module>()
# ----> 1 df.boxplot(column='initial_cost', by='G', rot=90)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#    2255     ax = boxplot(self, column=column, by=by, ax=ax, fontsize=fontsize,
#    2256                  grid=grid, rot=rot, figsize=figsize, layout=layout,
# -> 2257                  return_type=return_type, **kwds)
#    2258     plt.draw_if_interactive()
#    2259     return ax
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in boxplot(data, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#    2224                                          by=by, grid=grid, figsize=figsize,
# ...

# %%
df.boxplot(column='ge', by='cst', rot=90)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-53887af26796> in <module>()
# ----> 1 df.boxplot(column='ge', by='cst', rot=90)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#    2255     ax = boxplot(self, column=column, by=by, ax=ax, fontsize=fontsize,
#    2256                  grid=grid, rot=rot, figsize=figsize, layout=layout,
# -> 2257                  return_type=return_type, **kwds)
#    2258     plt.draw_if_interactive()
#    2259     return ax
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in boxplot(data, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#    2224                                          by=by, grid=grid, figsize=figsize,
# ...

# %%
sns.countplot(x='cut', data=df)
sns.despine()
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-41fa2f961cc5> in <module>()
# ----> 1 sns.countplot(x='cut', data=df)
#       2 sns.despine()
#       3 plt.tight_layout()
#
# NameError: name 'sns' is not defined

# %%
sns.countplot(x='A', data=df)
sns.despine()
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-3f864a114d0c> in <module>()
# ----> 1 sns.countplot(x='A', data=df)
#       2 sns.despine()
#       3 plt.tight_layout()
#
# NameError: name 'sns' is not defined

# %%
import pandas as pd
df=pd.read_csv("Z:\sample.csv")
print(df)
# Out:
#      F     G  Good Good.1    Vg Good.2  Y  Unmarried  V  Paid   ...     \
# 0    M   OBC    Vg     Vg    Vg     Vg  N  Unmarried  V  Paid   ...
# 1    F   OBC  Good   Good    Vg   Good  N  Unmarried  V  Paid   ...
# 2    M  MOBC  Pass   Good    Vg   Good  N  Unmarried  V  Paid   ...
# 3    M     G  Good   Good    Vg     Vg  N  Unmarried  V  Paid   ...
# 4    M   OBC    Vg   Good    Vg     Vg  N  Unmarried  V  Paid   ...
# 5    F   OBC  Good     Vg  Good   Good  N  Unmarried  V  Paid   ...
# 6    F   OBC  Good   Good  Good   Good  N  Unmarried  V  Paid   ...
# 7    F  MOBC    Vg   Good  Good     Vg  Y  Unmarried  V  Paid   ...
# 8    F   OBC    Vg     Vg  Good     Vg  Y  Unmarried  V  Paid   ...
# 9    M    ST    Vg     Vg  Good     Vg  N  Unmarried  V  Paid   ...
# 10   F   OBC    Vg     Vg  Good     Vg  N  Unmarried  V  Paid   ...
# 11   M   OBC  Good   Good  Good   Good  Y  Unmarried  V  Paid   ...
# 12   M   OBC  Good   Good  Pass     Vg  N  Unmarried  V  Paid   ...
# ...

# %%
import pandas as pd
df=pd.read_csv("Z:\sample.csv")
print(df)
# Out:
#     gender   cst  Good Good.1    Vg Good.2  Y  Unmarried  V  Paid   ...     \
# 0        M   OBC    Vg     Vg    Vg     Vg  N  Unmarried  V  Paid   ...
# 1        F   OBC  Good   Good    Vg   Good  N  Unmarried  V  Paid   ...
# 2        M  MOBC  Pass   Good    Vg   Good  N  Unmarried  V  Paid   ...
# 3        M     G  Good   Good    Vg     Vg  N  Unmarried  V  Paid   ...
# 4        M   OBC    Vg   Good    Vg     Vg  N  Unmarried  V  Paid   ...
# 5        F   OBC  Good     Vg  Good   Good  N  Unmarried  V  Paid   ...
# 6        F   OBC  Good   Good  Good   Good  N  Unmarried  V  Paid   ...
# 7        F  MOBC    Vg   Good  Good     Vg  Y  Unmarried  V  Paid   ...
# 8        F   OBC    Vg     Vg  Good     Vg  Y  Unmarried  V  Paid   ...
# 9        M    ST    Vg     Vg  Good     Vg  N  Unmarried  V  Paid   ...
# 10       F   OBC    Vg     Vg  Good     Vg  N  Unmarried  V  Paid   ...
# 11       M   OBC  Good   Good  Good   Good  Y  Unmarried  V  Paid   ...
# ...

# %%
df.describe()
# Out:
#        gender  cst  Good Good.1   Vg Good.2    Y  Unmarried    V  Paid  ...    \
# count     130  130   130    130  130    130  130        130  129   130  ...
# unique      2    5     4      4    4      4    2          1    2     2  ...
# top         M  OBC  Good   Good   Vg   Good    N  Unmarried    V  Paid  ...
# freq       72   57    58     64   62     53   78        130   90    75  ...
#
#          Um   10   Farmer  Housewife  Large     Poor  Govt  Asm  Small Good.3
# count   130  130      130        130    130      130   130  130    130    130
# unique    6    6        5          5      3        3     2    4      3      3
# top      Um   Um  Service  Housewife  Large  Average  Govt  Eng  Small   Good
# freq     39   52       38        114     57       59    90   62     77     55
#
# [4 rows x 22 columns]

# %%
df.boxplot(column='gender', by='cst',Rot=130)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-cfef0d3a3a1b> in <module>()
# ----> 1 df.boxplot(column='gender', by='cst',Rot=130)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#    2255     ax = boxplot(self, column=column, by=by, ax=ax, fontsize=fontsize,
#    2256                  grid=grid, rot=rot, figsize=figsize, layout=layout,
# -> 2257                  return_type=return_type, **kwds)
#    2258     plt.draw_if_interactive()
#    2259     return ax
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in boxplot(data, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#    2224                                          by=by, grid=grid, figsize=figsize,
# ...

# %%
import pandas as pd

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import statistics as st
from scipy.io import arff
from io import StringIO
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
('Z:\test.csv')
df=pd.DataFrame(data[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-84e28fe0aa7c> in <module>()
#       1 ('Z:\test.csv')
# ----> 2 df=pd.DataFrame(data[0])
#
# NameError: name 'data' is not defined

# %%
df=pd.read_csv("Z:\sample.csv")
print(df)
# Out:
#     gender   cst   tnp   twp   iap   esp arr         ms ls    as   ...     \
# 0        M   OBC    Vg    Vg    Vg    Vg   N  Unmarried  V  Paid   ...
# 1        F   OBC  Good  Good    Vg  Good   N  Unmarried  V  Paid   ...
# 2        M  MOBC  Pass  Good    Vg  Good   N  Unmarried  V  Paid   ...
# 3        M     G  Good  Good    Vg    Vg   N  Unmarried  V  Paid   ...
# 4        M   OBC    Vg  Good    Vg    Vg   N  Unmarried  V  Paid   ...
# 5        F   OBC  Good    Vg  Good  Good   N  Unmarried  V  Paid   ...
# 6        F   OBC  Good  Good  Good  Good   N  Unmarried  V  Paid   ...
# 7        F  MOBC    Vg  Good  Good    Vg   Y  Unmarried  V  Paid   ...
# 8        F   OBC    Vg    Vg  Good    Vg   Y  Unmarried  V  Paid   ...
# 9        M    ST    Vg    Vg  Good    Vg   N  Unmarried  V  Paid   ...
# 10       F   OBC    Vg    Vg  Good    Vg   N  Unmarried  V  Paid   ...
# 11       M   OBC  Good  Good  Good  Good   Y  Unmarried  V  Paid   ...
# ...

# %%
df.head()
# Out:
#   gender   cst   tnp   twp iap   esp arr         ms ls    as   ...     fq  mq  \
# 0      M   OBC    Vg    Vg  Vg    Vg   N  Unmarried  V  Paid   ...     Um  Il
# 1      F   OBC  Good  Good  Vg  Good   N  Unmarried  V  Paid   ...     12  10
# 2      M  MOBC  Pass  Good  Vg  Good   N  Unmarried  V  Paid   ...     12  Um
# 3      M     G  Good  Good  Vg    Vg   N  Unmarried  V  Paid   ...     10  12
# 4      M   OBC    Vg  Good  Vg    Vg   N  Unmarried  V  Paid   ...     10  Um
#
#          fo         mo    Large       sh       ss   me       td      atd
# 0   Service    Service       nf     Poor     Govt  Asm  Average  Average
# 1   Service  Housewife  Average  Average     Govt  Asm    Large     Good
# 2  Business   Business    Large     Poor     Govt  Asm  Average  Average
# 3   Service  Housewife    Large     Poor  Private  Asm    Small     Good
# 4    Farmer  Housewife    Small     Poor  Private  Eng  Average  Average
#
# [5 rows x 22 columns]

# %%
print(df.shape)
# Out:
# (130, 22)

# %%
df.isnull().sum()
# Out:
# gender    0
# cst       0
# tnp       0
# twp       0
# iap       0
# esp       0
# arr       0
# ms        0
# ls        1
# as        0
# fms       0
# fi        0
# fq        0
# mq        0
# fo        0
# mo        0
# Large     0
# sh        0
# ss        0
# me        0
# td        0
# atd       0
# dtype: int64

# %%
df.mean()
# Out:
# Series([], dtype: float64)

# %%
df.median()
# Out:
# Series([], dtype: float64)

# %%
df.mode()
# Out:
#   gender  cst   tnp   twp iap   esp arr         ms ls    as  ...   fq  mq  \
# 0      M  OBC  Good  Good  Vg  Good   N  Unmarried  V  Paid  ...   Um  Um
#
#         fo         mo  Large       sh    ss   me     td   atd
# 0  Service  Housewife  Large  Average  Govt  Eng  Small  Good
#
# [1 rows x 22 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#breakdown by class
sns.countplot(x="fo", data=df, palette="muted");
plt.show()

# %%
df['Fail'] = np.where(df['tnp']=='best',1,0)
sns.factorplot('tnp','Fail',data=df,size=5)

# %%
pd.crosstab(df['sh'],df['atd'])
# Out:
# atd      Average  Good  Poor
# sh
# Average       18    27    14
# Good           9    15     3
# Poor          20    13    11

# %%
sns.countplot(x=['A'],data=df,palette='PuBu')
plt.show()

# %%
df.['A'].value_counts()
# Out:
#   File "<ipython-input-44-e351d7aa8bf4>", line 1
#     df.['A'].value_counts()
#        ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import statistics as st
from scipy.io import arff
from io import StringIO
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = arff.loadarff('D:\Sapfile1.arff')
df=pd.DataFrame(data[0])

# %%
df.head()
# Out:
#      ge      cst      tnp      twp    iap      esp   arr            ms    ls  \
# 0  b'F'     b'G'  b'Good'  b'Good'  b'Vg'  b'Good'  b'Y'  b'Unmarried'  b'V'
# 1  b'M'   b'OBC'    b'Vg'    b'Vg'  b'Vg'    b'Vg'  b'N'  b'Unmarried'  b'V'
# 2  b'F'   b'OBC'  b'Good'  b'Good'  b'Vg'  b'Good'  b'N'  b'Unmarried'  b'V'
# 3  b'M'  b'MOBC'  b'Pass'  b'Good'  b'Vg'  b'Good'  b'N'  b'Unmarried'  b'V'
# 4  b'M'     b'G'  b'Good'  b'Good'  b'Vg'    b'Vg'  b'N'  b'Unmarried'  b'V'
#
#         as     ...         fq     mq           fo            mo          nf  \
# 0  b'Paid'     ...      b'Um'  b'10'    b'Farmer'  b'Housewife'    b'Large'
# 1  b'Paid'     ...      b'Um'  b'Il'   b'Service'    b'Service'    b'Small'
# 2  b'Paid'     ...      b'12'  b'10'   b'Service'  b'Housewife'  b'Average'
# 3  b'Paid'     ...      b'12'  b'Um'  b'Business'   b'Business'    b'Large'
# 4  b'Paid'     ...      b'10'  b'12'   b'Service'  b'Housewife'    b'Large'
#
# ...

# %%
print(df.shape)
# Out:
# (131, 22)

# %%
df.isnull().sum()
# Out:
# ge     0
# cst    0
# tnp    0
# twp    0
# iap    0
# esp    0
# arr    0
# ms     0
# ls     0
# as     0
# fmi    0
# fs     0
# fq     0
# mq     0
# fo     0
# mo     0
# nf     0
# sh     0
# ss     0
# me     0
# tt     0
# atd    0
# dtype: int64

# %%
df.median()
# Out:
# Series([], dtype: float64)

# %%
df.mode()
# Out:
#      ge     cst      tnp      twp    iap      esp   arr            ms    ls  \
# 0  b'M'  b'OBC'  b'Good'  b'Good'  b'Vg'  b'Good'  b'N'  b'Unmarried'  b'V'
#
#         as   ...        fq     mq          fo            mo        nf  \
# 0  b'Paid'   ...     b'Um'  b'Um'  b'Service'  b'Housewife'  b'Large'
#
#            sh       ss      me        tt      atd
# 0  b'Average'  b'Govt'  b'Eng'  b'Small'  b'Good'
#
# [1 rows x 22 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#breakdown by class
sns.countplot(x="fo", data=df, palette="muted");
plt.show()

# %%
df['Fail'] = np.where(df['tnp']=='best',1,0)
sns.factorplot('tnp','Fail',data=df,size=5)

# %%
pd.crosstab(df['sh'],df['atd'])
# Out:
# atd         b'Average'  b'Good'  b'Poor'
# sh
# b'Average'          18       27       14
# b'Good'              9       15        3
# b'Poor'             20       14       11

# %%
sns.countplot(x='tt',data=df,palette='PuBu')
plt.show()

# %%
df.tt.value_counts()
# Out:
# b'Small'      78
# b'Average'    43
# b'Large'      10
# Name: tt, dtype: int64

# %%
sns.countplot(x='cst',data = df, hue='tt',palette='bright')
plt.show()

# %%
sns.factorplot('twp','Fail',data=df)
